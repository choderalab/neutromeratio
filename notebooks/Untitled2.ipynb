# %%
# %matplotlib inline

from simtk import unit
import numpy as np
from tqdm import tqdm
import mdtraj as md
import nglview
from rdkit import Chem
from rdkit.Chem import AllChem
import neutromeratio
import matplotlib.pyplot as plt
import pickle
import torchani
import torch
from neutromeratio.constants import device, platform, kT, exclude_set
import sys, os
from tqdm import tqdm


# name of the system
idx = 10
# number of steps
n_steps = 10000
# diameter
diameter_in_angstrom = 16
# where to write the results
base_path = 'test'

mode = 'forward'

protocol = []
exp_results = pickle.load(open('../data/exp_results.pickle', 'rb'))
for name in sorted(exp_results):
    if name in exclude_set:
        continue
    for lambda_value in np.linspace(0,1,21):
        protocol.append((name, np.round(lambda_value, 2)))

name, lambda_value = protocol[idx-1]
print(name)
print(lambda_value)

t1_smiles = exp_results[name]['t1-smiles']
t2_smiles = exp_results[name]['t2-smiles']

# generate both rdkit mol
tautomer = neutromeratio.Tautomer(name=name, 
                                  initial_state_mol=neutromeratio.generate_rdkit_mol(t1_smiles), 
                                  final_state_mol=neutromeratio.generate_rdkit_mol(t2_smiles), 
                                  nr_of_conformations=2)
if mode == 'forward':
    tautomer.perform_tautomer_transformation_forward()
elif mode == 'reverse':
    tautomer.perform_tautomer_transformation_reverse()
else:
    raise RuntimeError('No tautomer reaction direction was specified.')

os.makedirs(f"{base_path}/{name}", exist_ok=True)
m = tautomer.add_droplet(tautomer.hybrid_topology, 
                            tautomer.hybrid_coords, 
                            diameter=diameter_in_angstrom * unit.angstrom,
                            restrain_hydrogens=True,
                            file=f"{base_path}/{name}/{name}_in_droplet_{mode}.pdb")

# define the alchemical atoms
alchemical_atoms=[tautomer.hybrid_hydrogen_idx_at_lambda_1, 
                  tautomer.hybrid_hydrogen_idx_at_lambda_0]

print('Nr of atoms: {}'.format(len(tautomer.ligand_in_water_atoms)))


# extract hydrogen donor idx and hydrogen idx for from_mol
model = neutromeratio.ani.LinearAlchemicalDualTopologyANI(alchemical_atoms=alchemical_atoms)
model = model.to(device)
torch.set_num_threads(2)

# perform initial sampling
energy_function = neutromeratio.ANI1_force_and_energy(
                                        model = model,
                                        atoms = tautomer.ligand_in_water_atoms,
                                        mol = None,
                                        adventure_mode=False
                                        )

tautomer.add_COM_for_hybrid_ligand(np.array([diameter_in_angstrom/2, 
                                             diameter_in_angstrom/2, 
                                             diameter_in_angstrom/2]) * unit.angstrom)

for r in tautomer.ligand_restraints:
    energy_function.add_restraint(r)

for r in tautomer.hybrid_ligand_restraints:
    energy_function.add_restraint(r)

for r in tautomer.solvent_restraints:
    energy_function.add_restraint(r)

for r in tautomer.com_restraints:
    energy_function.add_restraint(r)

print(lambda_value)
energy_and_force = lambda x : energy_function.calculate_force(x, lambda_value)
langevin = neutromeratio.LangevinDynamics(atoms = tautomer.ligand_in_water_atoms,                            
                            energy_and_force = energy_and_force)

x0 = tautomer.ligand_in_water_coordinates
x0, e_history = energy_function.minimize(x0, maxiter=1000, lambda_value=lambda_value) 

n_steps_junk = int(n_steps/10)

equilibrium_samples_global = []
energies_global = []
bias_global = []
stddev_global = []
penalty_global = []

for n_steps in [n_steps_junk] *10:
    equilibrium_samples, energies, bias, stddev, penalty = langevin.run_dynamics(x0, 
                                                                n_steps=round(n_steps), 
                                                                stepsize=0.5 * unit.femtosecond, 
                                                                progress_bar=True)
    
    # set new x0
    x0 = equilibrium_samples[-1]

    # add to global list
    equilibrium_samples_global += equilibrium_samples
    energies_global += energies
    bias_global += bias
    stddev_global += stddev
    penalty_global += penalty

    # save equilibrium energy values 
    f = open(f"{base_path}/{name}/{name}_lambda_{lambda_value:0.4f}_energy_in_droplet_{mode}.csv", 'w+')
    for e in energies_global[::20]:
        e_unitless = e / kT
        f.write('{}\n'.format(e_unitless))
    f.close()
    
    
    
    fig, ax1 = plt.subplots()
    plt.title('Energy/Ensemble stddev vs timestep')

    color = 'tab:red'
    ax1.set_xlabel('timestep (10 fs)')
    ax1.set_ylabel('energy [kT]', color=color)
    plt.plot([e / kT for e in energies_global[::20]],label='energy', color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    color = 'tab:blue'
    ax2.set_ylabel('ensemble stddev [kT]', color=color)  # we already handled the x-label with ax1
    plt.plot([e / kT for e in stddev_global[::20]],label='stddev', color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.set_xlabel('timestep (10 fs)')
    plt.legend()
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()
    plt.close()


    
    fig, ax1 = plt.subplots()
    plt.title('Ensemble stddev/applied bias vs timestep')

    color = 'tab:red'
    ax1.set_xlabel('timestep (10 fs)')
    ax1.set_ylabel('penalty [kT]', color=color)
    plt.plot([e / kT for e in penalty_global[::20]],label='penalty', color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
    color = 'tab:blue'
    ax2.set_ylabel('ensemble stddev [kT]', color=color)  # we already handled the x-label with ax1
    plt.plot([e / kT for e in stddev_global[::20]],label='stddev', color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.set_xlabel('timestep (10 fs)')
    plt.legend()
    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()
    plt.close()

    
    f = open(f"{base_path}/{name}/{name}_lambda_{lambda_value:0.4f}_bias_in_droplet_{mode}.csv", 'w+')
    for e in bias_global[::20]:
        e_unitless = e / kT
        f.write('{}\n'.format(e_unitless))
    f.close()


    equilibrium_samples_in_nm = [x.value_in_unit(unit.nanometer) for x in equilibrium_samples_global]
    ani_traj = md.Trajectory(equilibrium_samples_in_nm[::20], tautomer.ligand_in_water_topology)
    ani_traj.save(f"{base_path}/{name}/{name}_lambda_{lambda_value:0.4f}_in_droplet_{mode}.dcd", force_overwrite=True)
# Out:
# _ColormakerRegistry()
# [utils.py:141 - _init_num_threads()] NumExpr defaulting to 8 threads.
# [tautomers.py:48 - __init__()] Nr of conformations generated per tautomer: 2
# [tautomers.py:49 - __init__()] Chirality enforced: True
# [tautomers.py:431 - _perform_tautomer_transformation()] Index of atom that moves: 11.
# [tautomers.py:443 - _perform_tautomer_transformation()] Index of atom that donates hydrogen: 0
# [tautomers.py:461 - _perform_tautomer_transformation()] Index of atom that accepts hydrogen: 10
# SAMPLmol2
# 0.45
# [tautomers.py:165 - add_droplet()] Adding droplet ...
# Adding restraint to center to 19
# Adding restraint to center to 22
# Adding restraint to center to 25
# Adding restraint to center to 28
# Adding restraint to center to 31
# Adding restraint to center to 34
# Adding restraint to center to 37
# Adding restraint to center to 40
# Adding restraint to center to 43
# Adding restraint to center to 46
# Adding restraint to center to 49
# Adding restraint to center to 52
# Adding restraint to center to 55
# Adding restraint to center to 58
# Adding restraint to center to 61
# Adding restraint to center to 64
# Adding restraint to center to 67
# Adding restraint to center to 70
# Adding restraint to center to 73
# Adding restraint to center to 76
# Adding restraint to center to 79
# Adding restraint to center to 82
# Adding restraint to center to 85
# Adding restraint to center to 88
# Adding restraint to center to 91
# Adding restraint to center to 94
# Adding restraint to center to 97
# Adding restraint to center to 100
# Adding restraint to center to 103
# Adding restraint to center to 106
# Adding restraint to center to 109
# Adding restraint to center to 112
# Adding restraint to center to 115
# Adding restraint to center to 118
# Adding restraint to center to 121
# Adding restraint to center to 124
# Adding restraint to center to 127
# Adding restraint to center to 130
# Adding restraint to center to 133
# Adding restraint to center to 136
# Adding restraint to center to 139
# Adding restraint to center to 142
# Adding restraint to center to 145
# Adding restraint to center to 148
# Adding restraint to center to 151
# Adding restraint to center to 154
# Adding restraint to center to 157
# Adding restraint to center to 160
# Adding restraint to center to 163
# Adding restraint to center to 166
# Adding restraint to center to 169
# Adding restraint to center to 172
# Adding restraint to center to 175
# Adding restraint to center to 178
# Adding restraint to center to 181
# Adding restraint to center to 184
# Adding restraint to center to 187
# Adding restraint to center to 190
# Adding restraint to center to 193
# Adding restraint to center to 196
# Adding restraint to center to 199
# Adding restraint to center to 202
# Adding restraint to center to 205
# Adding restraint to center to 208
# Adding restraint to center to 211
# Adding restraint to center to 214
# Adding restraint to center to 217
# Adding restraint to center to 220
# Adding restraint to center to 223
# Adding restraint to center to 226
# Adding restraint to center to 229
# Adding restraint to center to 232
# Adding restraint to center to 235
# Adding restraint to center to 238
# Adding restraint to center to 241
# Nr of atoms: 244
# [restraints.py:180 - __init__()] Center Of Mass restraint added.
# 0.45
# Begin minimizing...
# [ani.py:318 - _linear_penalty()] Applying penalty: 0.0554099768879075 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 0.22285559976240885 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 0.23174134325692702 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 1.7734324522954594 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 0.49640904882941284 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 0.6049491201783008 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 0.8447623632400132 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 0.9668032630200254 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 1.3754273675880275 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 1.8140461302720947 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 3.769819223691725 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.039069910412089 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 5.387124532070902 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.153944318054892 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.048485509750891 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038440207765682 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038116231733044 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038310931763404 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038302479615178 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.038000261622586 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 5.387124532070902 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.352512536199708 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.109538706742705 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.054215163497226 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.041212600224837 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.048668920671689 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.042317233609189 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.040554842842972 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.041575464647508 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.042077705818384 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.04132781795305 kJ/mol
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.041118853084409 kJ/mol
# [ani.py:175 - minimize()] Minimization status: False
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: -16294873.736448
#          Iterations: 195
#          Function evaluations: 288
#          Gradient evaluations: 278
# [ani.py:318 - _linear_penalty()] Applying penalty: 4.039069910412089 kJ/mol
#   0%|          | 0/1000 [00:00<?, ?it/s][ani.py:318 - _linear_penalty()] Applying penalty: 14.614817028016875 kJ/mol
#   0%|          | 1/1000 [00:00<10:30,  1.58it/s, |force|=1e+4][ani.py:318 - _linear_penalty()] Applying penalty: 28.849686061439073 kJ/mol
#   0%|          | 2/1000 [00:01<10:33,  1.58it/s, |force|=1.4e+4][ani.py:318 - _linear_penalty()] Applying penalty: 35.924650062864764 kJ/mol
#   0%|          | 3/1000 [00:01<10:34,  1.57it/s, |force|=1.78e+4][ani.py:318 - _linear_penalty()] Applying penalty: 31.728377185903202 kJ/mol
#   0%|          | 4/1000 [00:02<10:40,  1.55it/s, |force|=2.02e+4][ani.py:318 - _linear_penalty()] Applying penalty: 17.996720070093144 kJ/mol
#   0%|          | 5/1000 [00:03<10:43,  1.55it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 3.2615792088580884 kJ/mol
#   3%|▎         | 27/1000 [00:17<10:19,  1.57it/s, |force|=1.7e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 9.581892241198986 kJ/mol
#   3%|▎         | 28/1000 [00:18<10:14,  1.58it/s, |force|=1.79e+4][ani.py:318 - _linear_penalty()] Applying penalty: 43.29009455246799 kJ/mol
#   3%|▎         | 29/1000 [00:18<10:08,  1.59it/s, |force|=1.89e+4][ani.py:318 - _linear_penalty()] Applying penalty: 96.13856879293509 kJ/mol
#   3%|▎         | 30/1000 [00:19<10:08,  1.59it/s, |force|=1.96e+4][ani.py:318 - _linear_penalty()] Applying penalty: 165.9702883351886 kJ/mol
#   3%|▎         | 31/1000 [00:20<10:14,  1.58it/s, |force|=1.95e+4][ani.py:318 - _linear_penalty()] Applying penalty: 243.28737036387926 kJ/mol
#   3%|▎         | 32/1000 [00:20<10:13,  1.58it/s, |force|=1.9e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 298.65963313551316 kJ/mol
#   3%|▎         | 33/1000 [00:21<10:14,  1.57it/s, |force|=1.83e+4][ani.py:318 - _linear_penalty()] Applying penalty: 311.63186542251015 kJ/mol
#   3%|▎         | 34/1000 [00:22<10:36,  1.52it/s, |force|=1.78e+4][ani.py:318 - _linear_penalty()] Applying penalty: 284.47259430472826 kJ/mol
#   4%|▎         | 35/1000 [00:22<10:24,  1.54it/s, |force|=1.73e+4][ani.py:318 - _linear_penalty()] Applying penalty: 220.66549013056988 kJ/mol
#   4%|▎         | 36/1000 [00:23<10:13,  1.57it/s, |force|=1.7e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 137.19627499863225 kJ/mol
#   4%|▎         | 37/1000 [00:24<10:57,  1.46it/s, |force|=1.7e+4][ani.py:318 - _linear_penalty()] Applying penalty: 69.61942388087077 kJ/mol
#   4%|▍         | 38/1000 [00:24<11:12,  1.43it/s, |force|=1.73e+4][ani.py:318 - _linear_penalty()] Applying penalty: 29.939333581671914 kJ/mol
#   4%|▍         | 39/1000 [00:25<12:15,  1.31it/s, |force|=1.74e+4][ani.py:318 - _linear_penalty()] Applying penalty: 13.21066822069986 kJ/mol
#   4%|▍         | 40/1000 [00:26<12:03,  1.33it/s, |force|=1.73e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8.551518236361009 kJ/mol
#   4%|▍         | 41/1000 [00:27<11:56,  1.34it/s, |force|=17069.0][ani.py:318 - _linear_penalty()] Applying penalty: 16.5548287032155 kJ/mol
#   4%|▍         | 42/1000 [00:28<11:54,  1.34it/s, |force|=1.67e+4][ani.py:318 - _linear_penalty()] Applying penalty: 52.907326542858364 kJ/mol
#   4%|▍         | 43/1000 [00:28<11:47,  1.35it/s, |force|=1.65e+4][ani.py:318 - _linear_penalty()] Applying penalty: 138.43969197637276 kJ/mol
#   4%|▍         | 44/1000 [00:29<11:33,  1.38it/s, |force|=1.67e+4][ani.py:318 - _linear_penalty()] Applying penalty: 281.47216499465753 kJ/mol
#   4%|▍         | 45/1000 [00:30<11:29,  1.38it/s, |force|=1.72e+4][ani.py:318 - _linear_penalty()] Applying penalty: 473.0287875740363 kJ/mol
#   5%|▍         | 46/1000 [00:30<11:29,  1.38it/s, |force|=1.78e+4][ani.py:318 - _linear_penalty()] Applying penalty: 700.6333608138118 kJ/mol
#   5%|▍         | 47/1000 [00:31<11:31,  1.38it/s, |force|=1.83e+4][ani.py:318 - _linear_penalty()] Applying penalty: 884.5449716565598 kJ/mol
#   5%|▍         | 48/1000 [00:32<12:01,  1.32it/s, |force|=1.87e+4][ani.py:318 - _linear_penalty()] Applying penalty: 929.6668138178475 kJ/mol
#   5%|▍         | 49/1000 [00:33<11:51,  1.34it/s, |force|=1.86e+4][ani.py:318 - _linear_penalty()] Applying penalty: 848.6731306372741 kJ/mol
#   5%|▌         | 50/1000 [00:33<11:16,  1.40it/s, |force|=1.83e+4][ani.py:318 - _linear_penalty()] Applying penalty: 684.2585964024571 kJ/mol
#   5%|▌         | 51/1000 [00:34<10:58,  1.44it/s, |force|=1.82e+4][ani.py:318 - _linear_penalty()] Applying penalty: 503.7206367094888 kJ/mol
#   5%|▌         | 52/1000 [00:35<10:36,  1.49it/s, |force|=1.85e+4][ani.py:318 - _linear_penalty()] Applying penalty: 350.99069487125365 kJ/mol
#   5%|▌         | 53/1000 [00:35<10:25,  1.51it/s, |force|=1.89e+4][ani.py:318 - _linear_penalty()] Applying penalty: 248.3447922180654 kJ/mol
#   5%|▌         | 54/1000 [00:36<10:36,  1.49it/s, |force|=1.9e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 195.4649609785392 kJ/mol
#   6%|▌         | 55/1000 [00:37<10:42,  1.47it/s, |force|=1.88e+4][ani.py:318 - _linear_penalty()] Applying penalty: 185.9116425265626 kJ/mol
#   6%|▌         | 56/1000 [00:37<10:43,  1.47it/s, |force|=1.85e+4][ani.py:318 - _linear_penalty()] Applying penalty: 209.0834832207921 kJ/mol
#   6%|▌         | 57/1000 [00:38<10:48,  1.45it/s, |force|=1.81e+4][ani.py:318 - _linear_penalty()] Applying penalty: 246.18284692835678 kJ/mol
#   6%|▌         | 58/1000 [00:39<11:07,  1.41it/s, |force|=1.77e+4][ani.py:318 - _linear_penalty()] Applying penalty: 295.244677337476 kJ/mol
#   6%|▌         | 59/1000 [00:39<11:02,  1.42it/s, |force|=1.76e+4][ani.py:318 - _linear_penalty()] Applying penalty: 355.9065225079292 kJ/mol
#   6%|▌         | 60/1000 [00:40<10:48,  1.45it/s, |force|=1.77e+4][ani.py:318 - _linear_penalty()] Applying penalty: 429.72653012605383 kJ/mol
#   6%|▌         | 61/1000 [00:41<10:28,  1.49it/s, |force|=1.83e+4][ani.py:318 - _linear_penalty()] Applying penalty: 483.0080233452084 kJ/mol
#   6%|▌         | 62/1000 [00:41<10:18,  1.52it/s, |force|=1.87e+4][ani.py:318 - _linear_penalty()] Applying penalty: 503.15292636337443 kJ/mol
#   6%|▋         | 63/1000 [00:42<10:12,  1.53it/s, |force|=1.88e+4][ani.py:318 - _linear_penalty()] Applying penalty: 502.19853382082414 kJ/mol
#   6%|▋         | 64/1000 [00:43<10:14,  1.52it/s, |force|=1.86e+4][ani.py:318 - _linear_penalty()] Applying penalty: 467.8266261780259 kJ/mol
#   6%|▋         | 65/1000 [00:43<10:39,  1.46it/s, |force|=1.83e+4][ani.py:318 - _linear_penalty()] Applying penalty: 408.7954846626341 kJ/mol
#   7%|▋         | 66/1000 [00:44<10:44,  1.45it/s, |force|=1.79e+4][ani.py:318 - _linear_penalty()] Applying penalty: 350.33880025672494 kJ/mol
#   7%|▋         | 67/1000 [00:45<10:49,  1.44it/s, |force|=1.78e+4][ani.py:318 - _linear_penalty()] Applying penalty: 302.6321661143804 kJ/mol
#   7%|▋         | 68/1000 [00:46<10:46,  1.44it/s, |force|=1.8e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 258.63204911737193 kJ/mol
#   7%|▋         | 69/1000 [00:46<10:43,  1.45it/s, |force|=1.85e+4][ani.py:318 - _linear_penalty()] Applying penalty: 226.14275397762188 kJ/mol
#   7%|▋         | 70/1000 [00:47<10:27,  1.48it/s, |force|=1.92e+4][ani.py:318 - _linear_penalty()] Applying penalty: 215.79737846370838 kJ/mol
#   7%|▋         | 71/1000 [00:47<10:12,  1.52it/s, |force|=1.96e+4][ani.py:318 - _linear_penalty()] Applying penalty: 223.11815480917082 kJ/mol
#   7%|▋         | 72/1000 [00:48<10:05,  1.53it/s, |force|=1.96e+4][ani.py:318 - _linear_penalty()] Applying penalty: 242.2393585607548 kJ/mol
#   7%|▋         | 73/1000 [00:49<10:04,  1.53it/s, |force|=1.91e+4][ani.py:318 - _linear_penalty()] Applying penalty: 283.3959766382092 kJ/mol
#   7%|▋         | 74/1000 [00:49<10:08,  1.52it/s, |force|=1.85e+4][ani.py:318 - _linear_penalty()] Applying penalty: 326.0246491226818 kJ/mol
#   8%|▊         | 75/1000 [00:50<10:23,  1.48it/s, |force|=1.8e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 355.2712713195399 kJ/mol
#   8%|▊         | 76/1000 [00:51<10:09,  1.52it/s, |force|=1.78e+4][ani.py:318 - _linear_penalty()] Applying penalty: 375.6837919626749 kJ/mol
#   8%|▊         | 77/1000 [00:51<10:01,  1.53it/s, |force|=1.79e+4][ani.py:318 - _linear_penalty()] Applying penalty: 399.6310986000083 kJ/mol
#   8%|▊         | 78/1000 [00:52<10:13,  1.50it/s, |force|=1.82e+4][ani.py:318 - _linear_penalty()] Applying penalty: 412.54757994110713 kJ/mol
#   8%|▊         | 79/1000 [00:53<10:09,  1.51it/s, |force|=1.87e+4][ani.py:318 - _linear_penalty()] Applying penalty: 395.6792569812163 kJ/mol
#   8%|▊         | 80/1000 [00:53<10:07,  1.52it/s, |force|=1.92e+4][ani.py:318 - _linear_penalty()] Applying penalty: 360.9689638485782 kJ/mol
#   8%|▊         | 81/1000 [00:54<10:01,  1.53it/s, |force|=1.95e+4][ani.py:318 - _linear_penalty()] Applying penalty: 309.35392070423234 kJ/mol
#   8%|▊         | 82/1000 [00:55<09:54,  1.54it/s, |force|=1.94e+4][ani.py:318 - _linear_penalty()] Applying penalty: 231.75732896120476 kJ/mol
#   8%|▊         | 83/1000 [00:55<09:46,  1.56it/s, |force|=1.9e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 148.6468403616922 kJ/mol
#   8%|▊         | 84/1000 [00:56<09:50,  1.55it/s, |force|=1.86e+4][ani.py:318 - _linear_penalty()] Applying penalty: 91.88553037860355 kJ/mol
#   8%|▊         | 85/1000 [00:57<09:42,  1.57it/s, |force|=1.83e+4][ani.py:318 - _linear_penalty()] Applying penalty: 65.44370083959014 kJ/mol
#   9%|▊         | 86/1000 [00:57<10:02,  1.52it/s, |force|=1.83e+4][ani.py:318 - _linear_penalty()] Applying penalty: 68.52400843309445 kJ/mol
#   9%|▊         | 87/1000 [00:58<10:22,  1.47it/s, |force|=1.85e+4][ani.py:318 - _linear_penalty()] Applying penalty: 106.60438859658333 kJ/mol
#   9%|▉         | 88/1000 [00:59<10:13,  1.49it/s, |force|=1.89e+4][ani.py:318 - _linear_penalty()] Applying penalty: 187.6622897354635 kJ/mol
#   9%|▉         | 89/1000 [00:59<10:03,  1.51it/s, |force|=1.92e+4][ani.py:318 - _linear_penalty()] Applying penalty: 298.2214885340596 kJ/mol
#   9%|▉         | 90/1000 [01:00<09:51,  1.54it/s, |force|=1.92e+4][ani.py:318 - _linear_penalty()] Applying penalty: 411.8888197244163 kJ/mol
#   9%|▉         | 91/1000 [01:01<09:41,  1.56it/s, |force|=1.89e+4][ani.py:318 - _linear_penalty()] Applying penalty: 497.08077495474396 kJ/mol
#   9%|▉         | 92/1000 [01:01<09:41,  1.56it/s, |force|=1.85e+4][ani.py:318 - _linear_penalty()] Applying penalty: 539.2239973724446 kJ/mol
#   9%|▉         | 93/1000 [01:02<09:48,  1.54it/s, |force|=1.83e+4][ani.py:318 - _linear_penalty()] Applying penalty: 534.7367857024514 kJ/mol
#   9%|▉         | 94/1000 [01:03<09:54,  1.52it/s, |force|=1.85e+4][ani.py:318 - _linear_penalty()] Applying penalty: 475.2450288168686 kJ/mol
#  10%|▉         | 95/1000 [01:03<09:55,  1.52it/s, |force|=1.88e+4][ani.py:318 - _linear_penalty()] Applying penalty: 380.4612471965575 kJ/mol
#  10%|▉         | 96/1000 [01:04<09:49,  1.53it/s, |force|=1.91e+4][ani.py:318 - _linear_penalty()] Applying penalty: 277.68268420537623 kJ/mol
#  10%|▉         | 97/1000 [01:05<10:05,  1.49it/s, |force|=1.91e+4][ani.py:318 - _linear_penalty()] Applying penalty: 184.80037529750683 kJ/mol
#  10%|▉         | 98/1000 [01:05<10:09,  1.48it/s, |force|=1.9e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 115.60925222539896 kJ/mol
#  10%|▉         | 99/1000 [01:06<10:11,  1.47it/s, |force|=1.87e+4][ani.py:318 - _linear_penalty()] Applying penalty: 76.42699515393089 kJ/mol
#  10%|█         | 100/1000 [01:07<10:26,  1.44it/s, |force|=1.83e+4][ani.py:318 - _linear_penalty()] Applying penalty: 67.24223509141923 kJ/mol
#  10%|█         | 101/1000 [01:07<10:37,  1.41it/s, |force|=1.8e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 77.54687333570108 kJ/mol
#  10%|█         | 102/1000 [01:08<10:16,  1.46it/s, |force|=1.81e+4][ani.py:318 - _linear_penalty()] Applying penalty: 108.86226758313697 kJ/mol
#  10%|█         | 103/1000 [01:09<10:32,  1.42it/s, |force|=1.86e+4][ani.py:318 - _linear_penalty()] Applying penalty: 160.58253672923456 kJ/mol
#  10%|█         | 104/1000 [01:10<10:47,  1.38it/s, |force|=1.92e+4][ani.py:318 - _linear_penalty()] Applying penalty: 215.45822062348017 kJ/mol
#  10%|█         | 105/1000 [01:10<10:46,  1.39it/s, |force|=1.98e+4][ani.py:318 - _linear_penalty()] Applying penalty: 247.45598139256595 kJ/mol
#  11%|█         | 106/1000 [01:11<10:57,  1.36it/s, |force|=2.02e+4][ani.py:318 - _linear_penalty()] Applying penalty: 242.42372423872573 kJ/mol
#  11%|█         | 107/1000 [01:12<10:51,  1.37it/s, |force|=2e+4]   [ani.py:318 - _linear_penalty()] Applying penalty: 196.0710695126232 kJ/mol
#  11%|█         | 108/1000 [01:12<10:26,  1.42it/s, |force|=1.95e+4][ani.py:318 - _linear_penalty()] Applying penalty: 132.89973115458008 kJ/mol
#  11%|█         | 109/1000 [01:13<10:16,  1.45it/s, |force|=1.9e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 77.32335266715545 kJ/mol
#  11%|█         | 110/1000 [01:14<10:07,  1.47it/s, |force|=1.9e+4][ani.py:318 - _linear_penalty()] Applying penalty: 37.39715710300389 kJ/mol
#  11%|█         | 111/1000 [01:14<09:55,  1.49it/s, |force|=1.94e+4][ani.py:318 - _linear_penalty()] Applying penalty: 11.137332008256601 kJ/mol
#  11%|█         | 112/1000 [01:15<09:43,  1.52it/s, |force|=2e+4]   [ani.py:318 - _linear_penalty()] Applying penalty: 0.2644696307958902 kJ/mol
#  12%|█▏        | 124/1000 [01:23<09:21,  1.56it/s, |force|=2.01e+4][ani.py:318 - _linear_penalty()] Applying penalty: 2.0931233622265415 kJ/mol
#  12%|█▎        | 125/1000 [01:23<09:21,  1.56it/s, |force|=1.95e+4][ani.py:318 - _linear_penalty()] Applying penalty: 6.135619359511795 kJ/mol
#  13%|█▎        | 126/1000 [01:24<09:16,  1.57it/s, |force|=1.92e+4][ani.py:318 - _linear_penalty()] Applying penalty: 6.646258288341586 kJ/mol
#  13%|█▎        | 127/1000 [01:25<09:30,  1.53it/s, |force|=1.91e+4][ani.py:318 - _linear_penalty()] Applying penalty: 2.575843248764548 kJ/mol
#  13%|█▎        | 128/1000 [01:25<09:31,  1.53it/s, |force|=1.92e+4][ani.py:318 - _linear_penalty()] Applying penalty: 0.09511383586711986 kJ/mol
#  13%|█▎        | 129/1000 [01:26<09:30,  1.53it/s, |force|=1.95e+4][ani.py:318 - _linear_penalty()] Applying penalty: 0.024172544523575278 kJ/mol
#  13%|█▎        | 130/1000 [01:27<09:22,  1.55it/s, |force|=2.01e+4][ani.py:318 - _linear_penalty()] Applying penalty: 0.35515731481115365 kJ/mol
#  13%|█▎        | 131/1000 [01:27<09:17,  1.56it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 15.25648644471992 kJ/mol
#  13%|█▎        | 132/1000 [01:28<09:20,  1.55it/s, |force|=2.11e+4][ani.py:318 - _linear_penalty()] Applying penalty: 78.2358198894292 kJ/mol
#  13%|█▎        | 133/1000 [01:28<09:19,  1.55it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 241.4042193208756 kJ/mol
#  13%|█▎        | 134/1000 [01:29<09:17,  1.55it/s, |force|=2.02e+4][ani.py:318 - _linear_penalty()] Applying penalty: 419.6165191270062 kJ/mol
#  14%|█▎        | 135/1000 [01:30<09:36,  1.50it/s, |force|=1.96e+4][ani.py:318 - _linear_penalty()] Applying penalty: 383.534662840329 kJ/mol
#  14%|█▎        | 136/1000 [01:31<09:46,  1.47it/s, |force|=1.96e+4][ani.py:318 - _linear_penalty()] Applying penalty: 343.31764316840713 kJ/mol
#  14%|█▎        | 137/1000 [01:31<09:40,  1.49it/s, |force|=2.03e+4][ani.py:318 - _linear_penalty()] Applying penalty: 514.4718420023031 kJ/mol
#  14%|█▍        | 138/1000 [01:32<09:44,  1.47it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 840.5954710393321 kJ/mol
#  14%|█▍        | 139/1000 [01:32<09:30,  1.51it/s, |force|=2.16e+4][ani.py:318 - _linear_penalty()] Applying penalty: 1093.2327709550048 kJ/mol
#  14%|█▍        | 140/1000 [01:33<09:25,  1.52it/s, |force|=2.2e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 1298.607344661466 kJ/mol
#  14%|█▍        | 141/1000 [01:34<09:43,  1.47it/s, |force|=2.16e+4][ani.py:318 - _linear_penalty()] Applying penalty: 1890.755948422481 kJ/mol
#  14%|█▍        | 142/1000 [01:35<10:02,  1.43it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 2550.7501108121123 kJ/mol
#  14%|█▍        | 143/1000 [01:35<10:21,  1.38it/s, |force|=1.86e+4][ani.py:318 - _linear_penalty()] Applying penalty: 2566.2996292744524 kJ/mol
#  14%|█▍        | 144/1000 [01:36<10:20,  1.38it/s, |force|=1.82e+4][ani.py:318 - _linear_penalty()] Applying penalty: 2491.715868139433 kJ/mol
#  14%|█▍        | 145/1000 [01:37<10:04,  1.41it/s, |force|=1.87e+4][ani.py:318 - _linear_penalty()] Applying penalty: 2878.1149644281013 kJ/mol
#  15%|█▍        | 146/1000 [01:37<09:56,  1.43it/s, |force|=2.01e+4][ani.py:318 - _linear_penalty()] Applying penalty: 3311.6926021055338 kJ/mol
#  15%|█▍        | 147/1000 [01:38<09:45,  1.46it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 3112.1687614789034 kJ/mol
#  15%|█▍        | 148/1000 [01:39<09:27,  1.50it/s, |force|=2.18e+4][ani.py:318 - _linear_penalty()] Applying penalty: 1907.203344391033 kJ/mol
#  15%|█▍        | 149/1000 [01:39<09:18,  1.52it/s, |force|=2.19e+4][ani.py:318 - _linear_penalty()] Applying penalty: 1067.2082531596084 kJ/mol
#  15%|█▌        | 150/1000 [01:40<09:07,  1.55it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 862.2019713204278 kJ/mol
#  15%|█▌        | 151/1000 [01:41<09:02,  1.57it/s, |force|=1.94e+4][ani.py:318 - _linear_penalty()] Applying penalty: 992.586307418825 kJ/mol
#  15%|█▌        | 152/1000 [01:41<09:12,  1.53it/s, |force|=1.88e+4][ani.py:318 - _linear_penalty()] Applying penalty: 1460.6867507798302 kJ/mol
#  15%|█▌        | 153/1000 [01:42<09:04,  1.55it/s, |force|=1.96e+4][ani.py:318 - _linear_penalty()] Applying penalty: 3314.5967850079533 kJ/mol
#  15%|█▌        | 154/1000 [01:43<08:56,  1.58it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 6517.014253321621 kJ/mol
#  16%|█▌        | 155/1000 [01:43<08:54,  1.58it/s, |force|=21234.9][ani.py:318 - _linear_penalty()] Applying penalty: 8020.834403429964 kJ/mol
#  16%|█▌        | 156/1000 [01:44<08:59,  1.57it/s, |force|=2.21e+4][ani.py:318 - _linear_penalty()] Applying penalty: 7755.488635586145 kJ/mol
#  16%|█▌        | 157/1000 [01:44<09:00,  1.56it/s, |force|=2.24e+4][ani.py:318 - _linear_penalty()] Applying penalty: 7681.205679211563 kJ/mol
#  16%|█▌        | 158/1000 [01:45<09:12,  1.52it/s, |force|=2.16e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8408.455588249059 kJ/mol
#  16%|█▌        | 159/1000 [01:46<09:08,  1.53it/s, |force|=2.03e+4][ani.py:318 - _linear_penalty()] Applying penalty: 9437.7612732676 kJ/mol
#  16%|█▌        | 160/1000 [01:46<09:07,  1.54it/s, |force|=1.91e+4][ani.py:318 - _linear_penalty()] Applying penalty: 10412.040114610616 kJ/mol
#  16%|█▌        | 161/1000 [01:47<09:07,  1.53it/s, |force|=1.85e+4][ani.py:318 - _linear_penalty()] Applying penalty: 11204.292129841784 kJ/mol
#  16%|█▌        | 162/1000 [01:48<09:16,  1.51it/s, |force|=1.86e+4][ani.py:318 - _linear_penalty()] Applying penalty: 11816.533494204685 kJ/mol
#  16%|█▋        | 163/1000 [01:48<09:06,  1.53it/s, |force|=1.94e+4][ani.py:318 - _linear_penalty()] Applying penalty: 12153.563253827922 kJ/mol
#  16%|█▋        | 164/1000 [01:49<09:01,  1.54it/s, |force|=2.05e+4][ani.py:318 - _linear_penalty()] Applying penalty: 12278.673673949836 kJ/mol
#  16%|█▋        | 165/1000 [01:50<08:59,  1.55it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 12392.432809977085 kJ/mol
#  17%|█▋        | 166/1000 [01:50<08:51,  1.57it/s, |force|=2.13e+4][ani.py:318 - _linear_penalty()] Applying penalty: 12796.19022053792 kJ/mol
#  17%|█▋        | 167/1000 [01:51<08:51,  1.57it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 13841.568604002421 kJ/mol
#  17%|█▋        | 168/1000 [01:52<09:20,  1.49it/s, |force|=1.99e+4][ani.py:318 - _linear_penalty()] Applying penalty: 14927.940236999222 kJ/mol
#  17%|█▋        | 169/1000 [01:52<09:37,  1.44it/s, |force|=1.9e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 14767.552763142394 kJ/mol
#  17%|█▋        | 170/1000 [01:53<09:18,  1.49it/s, |force|=1.91e+4][ani.py:318 - _linear_penalty()] Applying penalty: 13278.132184995038 kJ/mol
#  17%|█▋        | 171/1000 [01:54<09:10,  1.51it/s, |force|=2.04e+4][ani.py:318 - _linear_penalty()] Applying penalty: 12376.508288220914 kJ/mol
#  17%|█▋        | 172/1000 [01:54<08:59,  1.53it/s, |force|=2.17e+4][ani.py:318 - _linear_penalty()] Applying penalty: 13447.64737978257 kJ/mol
#  17%|█▋        | 173/1000 [01:55<08:53,  1.55it/s, |force|=2.26e+4][ani.py:318 - _linear_penalty()] Applying penalty: 16537.368343223177 kJ/mol
#  17%|█▋        | 174/1000 [01:56<08:47,  1.57it/s, |force|=2.25e+4][ani.py:318 - _linear_penalty()] Applying penalty: 19228.39344312709 kJ/mol
#  18%|█▊        | 175/1000 [01:56<08:57,  1.53it/s, |force|=2.2e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 19578.897339423413 kJ/mol
#  18%|█▊        | 176/1000 [01:57<08:56,  1.53it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 19093.940808725078 kJ/mol
#  18%|█▊        | 177/1000 [01:58<08:51,  1.55it/s, |force|=2.05e+4][ani.py:318 - _linear_penalty()] Applying penalty: 18496.923967099385 kJ/mol
#  18%|█▊        | 178/1000 [01:58<08:53,  1.54it/s, |force|=1.98e+4][ani.py:318 - _linear_penalty()] Applying penalty: 17779.370900624966 kJ/mol
#  18%|█▊        | 179/1000 [01:59<08:46,  1.56it/s, |force|=1.95e+4][ani.py:318 - _linear_penalty()] Applying penalty: 17089.214945747633 kJ/mol
#  18%|█▊        | 180/1000 [02:00<08:55,  1.53it/s, |force|=1.98e+4][ani.py:318 - _linear_penalty()] Applying penalty: 16157.922056676116 kJ/mol
#  18%|█▊        | 181/1000 [02:00<08:46,  1.55it/s, |force|=2.05e+4][ani.py:318 - _linear_penalty()] Applying penalty: 14451.0374509504 kJ/mol
#  18%|█▊        | 182/1000 [02:01<08:45,  1.56it/s, |force|=2.11e+4][ani.py:318 - _linear_penalty()] Applying penalty: 11632.450395192524 kJ/mol
#  18%|█▊        | 183/1000 [02:01<08:55,  1.53it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8591.352148048061 kJ/mol
#  18%|█▊        | 184/1000 [02:02<08:48,  1.54it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 6557.331888045966 kJ/mol
#  18%|█▊        | 185/1000 [02:03<08:41,  1.56it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 5923.796120914395 kJ/mol
#  19%|█▊        | 186/1000 [02:03<08:34,  1.58it/s, |force|=2e+4]   [ani.py:318 - _linear_penalty()] Applying penalty: 6499.406805464149 kJ/mol
#  19%|█▊        | 187/1000 [02:04<08:27,  1.60it/s, |force|=1.92e+4][ani.py:318 - _linear_penalty()] Applying penalty: 7601.41615861196 kJ/mol
#  19%|█▉        | 188/1000 [02:05<08:23,  1.61it/s, |force|=1.92e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8604.839136910618 kJ/mol
#  19%|█▉        | 189/1000 [02:05<08:20,  1.62it/s, |force|=1.97e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8999.722219649007 kJ/mol
#  19%|█▉        | 190/1000 [02:06<08:17,  1.63it/s, |force|=2.07e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8985.851358870535 kJ/mol
#  19%|█▉        | 191/1000 [02:06<08:16,  1.63it/s, |force|=2.17e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8624.555591124112 kJ/mol
#  19%|█▉        | 192/1000 [02:07<08:23,  1.60it/s, |force|=2.25e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8096.890309655685 kJ/mol
#  19%|█▉        | 193/1000 [02:08<08:31,  1.58it/s, |force|=2.27e+4][ani.py:318 - _linear_penalty()] Applying penalty: 7887.035104213649 kJ/mol
#  19%|█▉        | 194/1000 [02:08<08:26,  1.59it/s, |force|=2.2e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 8172.0893457979555 kJ/mol
#  20%|█▉        | 195/1000 [02:09<08:26,  1.59it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8210.31488077944 kJ/mol
#  20%|█▉        | 196/1000 [02:10<08:28,  1.58it/s, |force|=1.96e+4][ani.py:318 - _linear_penalty()] Applying penalty: 7743.758776122802 kJ/mol
#  20%|█▉        | 197/1000 [02:10<08:31,  1.57it/s, |force|=1.94e+4][ani.py:318 - _linear_penalty()] Applying penalty: 7588.035309875849 kJ/mol
#  20%|█▉        | 198/1000 [02:11<08:27,  1.58it/s, |force|=2.03e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8437.927273922742 kJ/mol
#  20%|█▉        | 199/1000 [02:11<08:29,  1.57it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 10718.628347653357 kJ/mol
#  20%|██        | 200/1000 [02:12<09:01,  1.48it/s, |force|=2.18e+4][ani.py:318 - _linear_penalty()] Applying penalty: 13792.704393973498 kJ/mol
#  20%|██        | 201/1000 [02:13<09:11,  1.45it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 15416.659549930668 kJ/mol
#  20%|██        | 202/1000 [02:14<09:53,  1.34it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 15226.472012065133 kJ/mol
#  20%|██        | 203/1000 [02:15<09:47,  1.36it/s, |force|=2.03e+4][ani.py:318 - _linear_penalty()] Applying penalty: 14796.274527043666 kJ/mol
#  20%|██        | 204/1000 [02:15<09:44,  1.36it/s, |force|=1.98e+4][ani.py:318 - _linear_penalty()] Applying penalty: 14545.430303822275 kJ/mol
#  20%|██        | 205/1000 [02:16<09:42,  1.36it/s, |force|=1.94e+4][ani.py:318 - _linear_penalty()] Applying penalty: 13889.19689216156 kJ/mol
#  21%|██        | 206/1000 [02:17<09:47,  1.35it/s, |force|=1.93e+4][ani.py:318 - _linear_penalty()] Applying penalty: 12142.414880913575 kJ/mol
#  21%|██        | 207/1000 [02:18<09:43,  1.36it/s, |force|=1.95e+4][ani.py:318 - _linear_penalty()] Applying penalty: 9465.737604604223 kJ/mol
#  21%|██        | 208/1000 [02:18<10:23,  1.27it/s, |force|=2.05e+4][ani.py:318 - _linear_penalty()] Applying penalty: 7494.292430474501 kJ/mol
#  21%|██        | 209/1000 [02:19<10:53,  1.21it/s, |force|=2.16e+4][ani.py:318 - _linear_penalty()] Applying penalty: 7208.482254413832 kJ/mol
#  21%|██        | 210/1000 [02:20<10:55,  1.20it/s, |force|=2.22e+4][ani.py:318 - _linear_penalty()] Applying penalty: 8516.78394511597 kJ/mol
#  21%|██        | 211/1000 [02:21<10:31,  1.25it/s, |force|=2.2e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 10515.522277384067 kJ/mol
#  21%|██        | 212/1000 [02:22<10:12,  1.29it/s, |force|=2.13e+4][ani.py:318 - _linear_penalty()] Applying penalty: 11964.528770774898 kJ/mol
#  21%|██▏       | 213/1000 [02:22<09:50,  1.33it/s, |force|=2.1e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 12917.328977039524 kJ/mol
#  21%|██▏       | 214/1000 [02:23<10:10,  1.29it/s, |force|=2.11e+4][ani.py:318 - _linear_penalty()] Applying penalty: 14052.046148900097 kJ/mol
#  22%|██▏       | 215/1000 [02:24<10:36,  1.23it/s, |force|=2.15e+4][ani.py:318 - _linear_penalty()] Applying penalty: 15746.87110101236 kJ/mol
#  22%|██▏       | 216/1000 [02:25<10:44,  1.22it/s, |force|=2.19e+4][ani.py:318 - _linear_penalty()] Applying penalty: 17274.111056494068 kJ/mol
#  22%|██▏       | 217/1000 [02:26<10:23,  1.26it/s, |force|=2.18e+4][ani.py:318 - _linear_penalty()] Applying penalty: 17493.727430486768 kJ/mol
#  22%|██▏       | 218/1000 [02:26<09:59,  1.30it/s, |force|=2.15e+4][ani.py:318 - _linear_penalty()] Applying penalty: 16882.684570584697 kJ/mol
#  22%|██▏       | 219/1000 [02:27<09:32,  1.36it/s, |force|=2.11e+4][ani.py:318 - _linear_penalty()] Applying penalty: 16081.842990617872 kJ/mol
#  22%|██▏       | 220/1000 [02:28<09:54,  1.31it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 16549.471751813933 kJ/mol
#  22%|██▏       | 221/1000 [02:28<09:33,  1.36it/s, |force|=2.03e+4][ani.py:318 - _linear_penalty()] Applying penalty: 18693.881477653482 kJ/mol
#  22%|██▏       | 222/1000 [02:29<09:12,  1.41it/s, |force|=1.97e+4][ani.py:318 - _linear_penalty()] Applying penalty: 21090.516294640915 kJ/mol
#  22%|██▏       | 223/1000 [02:30<09:02,  1.43it/s, |force|=1.91e+4][ani.py:318 - _linear_penalty()] Applying penalty: 21634.94594827527 kJ/mol
#  22%|██▏       | 224/1000 [02:31<08:59,  1.44it/s, |force|=1.95e+4][ani.py:318 - _linear_penalty()] Applying penalty: 21002.983372620092 kJ/mol
#  22%|██▎       | 225/1000 [02:31<08:56,  1.44it/s, |force|=2e+4]   [ani.py:318 - _linear_penalty()] Applying penalty: 20632.110068070386 kJ/mol
#  23%|██▎       | 226/1000 [02:32<09:07,  1.41it/s, |force|=2.05e+4][ani.py:318 - _linear_penalty()] Applying penalty: 20507.053046700512 kJ/mol
#  23%|██▎       | 227/1000 [02:33<09:21,  1.38it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 20480.679264250342 kJ/mol
#  23%|██▎       | 228/1000 [02:33<09:33,  1.35it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 18882.65953005999 kJ/mol
#  23%|██▎       | 229/1000 [02:34<10:26,  1.23it/s, |force|=2.11e+4][ani.py:318 - _linear_penalty()] Applying penalty: 16959.63553824268 kJ/mol
#  23%|██▎       | 230/1000 [02:35<10:23,  1.24it/s, |force|=2.17e+4][ani.py:318 - _linear_penalty()] Applying penalty: 18266.21174363727 kJ/mol
#  23%|██▎       | 231/1000 [02:36<10:13,  1.25it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 23375.98906901749 kJ/mol
#  23%|██▎       | 232/1000 [02:37<10:01,  1.28it/s, |force|=2.03e+4][ani.py:318 - _linear_penalty()] Applying penalty: 28695.260633545033 kJ/mol
#  23%|██▎       | 233/1000 [02:37<09:32,  1.34it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 30051.235446556842 kJ/mol
#  23%|██▎       | 234/1000 [02:38<09:09,  1.39it/s, |force|=2.21e+4][ani.py:318 - _linear_penalty()] Applying penalty: 30085.716014776088 kJ/mol
#  24%|██▎       | 235/1000 [02:39<08:52,  1.44it/s, |force|=2.21e+4][ani.py:318 - _linear_penalty()] Applying penalty: 29774.399672097315 kJ/mol
#  24%|██▎       | 236/1000 [02:39<08:34,  1.48it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 28310.89087762886 kJ/mol
#  24%|██▎       | 237/1000 [02:40<08:21,  1.52it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 25989.544979234415 kJ/mol
#  24%|██▍       | 238/1000 [02:41<08:24,  1.51it/s, |force|=2.1e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 24542.549395833244 kJ/mol
#  24%|██▍       | 239/1000 [02:41<08:17,  1.53it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 25707.361746465016 kJ/mol
#  24%|██▍       | 240/1000 [02:42<08:30,  1.49it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 28939.23531850305 kJ/mol
#  24%|██▍       | 241/1000 [02:43<08:56,  1.41it/s, |force|=2.01e+4][ani.py:318 - _linear_penalty()] Applying penalty: 31369.85333125388 kJ/mol
#  24%|██▍       | 242/1000 [02:44<08:57,  1.41it/s, |force|=2.03e+4][ani.py:318 - _linear_penalty()] Applying penalty: 33025.55771721681 kJ/mol
#  24%|██▍       | 243/1000 [02:44<08:40,  1.45it/s, |force|=2.1e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 34743.95621348897 kJ/mol
#  24%|██▍       | 244/1000 [02:45<08:42,  1.45it/s, |force|=2.1e+4][ani.py:318 - _linear_penalty()] Applying penalty: 35033.29628977901 kJ/mol
#  24%|██▍       | 245/1000 [02:46<09:01,  1.39it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 32231.205549703278 kJ/mol
#  25%|██▍       | 246/1000 [02:46<09:28,  1.33it/s, |force|=2.04e+4][ani.py:318 - _linear_penalty()] Applying penalty: 28224.120194012692 kJ/mol
#  25%|██▍       | 247/1000 [02:47<09:11,  1.37it/s, |force|=2.07e+4][ani.py:318 - _linear_penalty()] Applying penalty: 26672.908860740612 kJ/mol
#  25%|██▍       | 248/1000 [02:48<09:00,  1.39it/s, |force|=2.07e+4][ani.py:318 - _linear_penalty()] Applying penalty: 27493.342969955847 kJ/mol
#  25%|██▍       | 249/1000 [02:49<08:57,  1.40it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 28057.246355307452 kJ/mol
#  25%|██▌       | 250/1000 [02:49<08:42,  1.44it/s, |force|=2.07e+4][ani.py:318 - _linear_penalty()] Applying penalty: 27394.94333167957 kJ/mol
#  25%|██▌       | 251/1000 [02:50<08:25,  1.48it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 26683.380481742835 kJ/mol
#  25%|██▌       | 252/1000 [02:50<08:12,  1.52it/s, |force|=2.03e+4][ani.py:318 - _linear_penalty()] Applying penalty: 26262.39289213799 kJ/mol
#  25%|██▌       | 253/1000 [02:51<08:02,  1.55it/s, |force|=2.02e+4][ani.py:318 - _linear_penalty()] Applying penalty: 25619.750851643927 kJ/mol
#  25%|██▌       | 254/1000 [02:52<08:01,  1.55it/s, |force|=2.04e+4][ani.py:318 - _linear_penalty()] Applying penalty: 24186.000715683836 kJ/mol
#  26%|██▌       | 255/1000 [02:52<08:09,  1.52it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 21567.35114336501 kJ/mol
#  26%|██▌       | 256/1000 [02:53<08:02,  1.54it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 18550.26096073367 kJ/mol
#  26%|██▌       | 257/1000 [02:54<08:15,  1.50it/s, |force|=2.13e+4][ani.py:318 - _linear_penalty()] Applying penalty: 16675.141737257854 kJ/mol
#  26%|██▌       | 258/1000 [02:54<08:18,  1.49it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 16458.782918367568 kJ/mol
#  26%|██▌       | 259/1000 [02:55<08:06,  1.52it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 17167.937202712586 kJ/mol
#  26%|██▌       | 260/1000 [02:56<08:01,  1.54it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 17584.873704824557 kJ/mol
#  26%|██▌       | 261/1000 [02:56<07:52,  1.56it/s, |force|=2.1e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 18338.515671032736 kJ/mol
#  26%|██▌       | 262/1000 [02:57<07:46,  1.58it/s, |force|=2.13e+4][ani.py:318 - _linear_penalty()] Applying penalty: 19859.882197041825 kJ/mol
#  26%|██▋       | 263/1000 [02:58<07:45,  1.58it/s, |force|=2.1e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 22141.72708611886 kJ/mol
#  26%|██▋       | 264/1000 [02:58<07:40,  1.60it/s, |force|=2.02e+4][ani.py:318 - _linear_penalty()] Applying penalty: 24731.778167133638 kJ/mol
#  26%|██▋       | 265/1000 [02:59<07:38,  1.60it/s, |force|=1.95e+4][ani.py:318 - _linear_penalty()] Applying penalty: 27278.66489627803 kJ/mol
#  27%|██▋       | 266/1000 [02:59<07:49,  1.56it/s, |force|=1.95e+4][ani.py:318 - _linear_penalty()] Applying penalty: 30416.954401266932 kJ/mol
#  27%|██▋       | 267/1000 [03:00<07:47,  1.57it/s, |force|=1.98e+4][ani.py:318 - _linear_penalty()] Applying penalty: 34245.9613124352 kJ/mol
#  27%|██▋       | 268/1000 [03:01<07:44,  1.58it/s, |force|=2.02e+4][ani.py:318 - _linear_penalty()] Applying penalty: 37346.79632795139 kJ/mol
#  27%|██▋       | 269/1000 [03:01<07:42,  1.58it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 40806.655951010165 kJ/mol
#  27%|██▋       | 270/1000 [03:02<07:36,  1.60it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 43743.31276088148 kJ/mol
#  27%|██▋       | 271/1000 [03:03<07:36,  1.60it/s, |force|=2.07e+4][ani.py:318 - _linear_penalty()] Applying penalty: 43891.13387688892 kJ/mol
#  27%|██▋       | 272/1000 [03:03<07:32,  1.61it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 43063.13456995429 kJ/mol
#  27%|██▋       | 273/1000 [03:04<07:36,  1.59it/s, |force|=2.11e+4][ani.py:318 - _linear_penalty()] Applying penalty: 43190.65510549469 kJ/mol
#  27%|██▋       | 274/1000 [03:04<07:36,  1.59it/s, |force|=2.1e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 44806.91185526981 kJ/mol
#  28%|██▊       | 275/1000 [03:05<07:30,  1.61it/s, |force|=2.05e+4][ani.py:318 - _linear_penalty()] Applying penalty: 46969.05047450842 kJ/mol
#  28%|██▊       | 276/1000 [03:06<07:37,  1.58it/s, |force|=20220.2][ani.py:318 - _linear_penalty()] Applying penalty: 49113.76456740698 kJ/mol
#  28%|██▊       | 277/1000 [03:06<07:35,  1.59it/s, |force|=2.04e+4][ani.py:318 - _linear_penalty()] Applying penalty: 51542.34623928599 kJ/mol
#  28%|██▊       | 278/1000 [03:07<07:36,  1.58it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 57742.36440388122 kJ/mol
#  28%|██▊       | 279/1000 [03:08<07:37,  1.58it/s, |force|=2.15e+4][ani.py:318 - _linear_penalty()] Applying penalty: 67878.60548341135 kJ/mol
#  28%|██▊       | 280/1000 [03:08<07:36,  1.58it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 75289.33058007741 kJ/mol
#  28%|██▊       | 281/1000 [03:09<07:54,  1.51it/s, |force|=2.07e+4][ani.py:318 - _linear_penalty()] Applying penalty: 80208.86514981315 kJ/mol
#  28%|██▊       | 282/1000 [03:10<07:49,  1.53it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 84545.09926622959 kJ/mol
#  28%|██▊       | 283/1000 [03:10<07:48,  1.53it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 88311.56122529451 kJ/mol
#  28%|██▊       | 284/1000 [03:11<07:41,  1.55it/s, |force|=20484.1][ani.py:318 - _linear_penalty()] Applying penalty: 90849.05609277297 kJ/mol
#  28%|██▊       | 285/1000 [03:12<07:48,  1.52it/s, |force|=2.05e+4][ani.py:318 - _linear_penalty()] Applying penalty: 91616.54107707653 kJ/mol
#  29%|██▊       | 286/1000 [03:12<07:38,  1.56it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 94586.57748977053 kJ/mol
#  29%|██▊       | 287/1000 [03:13<07:30,  1.58it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 99634.45232911124 kJ/mol
#  29%|██▉       | 288/1000 [03:13<07:30,  1.58it/s, |force|=2.04e+4][ani.py:318 - _linear_penalty()] Applying penalty: 104277.85107780735 kJ/mol
#  29%|██▉       | 289/1000 [03:14<07:39,  1.55it/s, |force|=2e+4]   [ani.py:318 - _linear_penalty()] Applying penalty: 107060.08905664575 kJ/mol
#  29%|██▉       | 290/1000 [03:15<07:36,  1.56it/s, |force|=2e+4][ani.py:318 - _linear_penalty()] Applying penalty: 108798.68002634536 kJ/mol
#  29%|██▉       | 291/1000 [03:15<07:35,  1.56it/s, |force|=2.02e+4][ani.py:318 - _linear_penalty()] Applying penalty: 110104.2808263003 kJ/mol
#  29%|██▉       | 292/1000 [03:16<07:39,  1.54it/s, |force|=2.04e+4][ani.py:318 - _linear_penalty()] Applying penalty: 110675.07230011278 kJ/mol
#  29%|██▉       | 293/1000 [03:17<07:39,  1.54it/s, |force|=2.05e+4][ani.py:318 - _linear_penalty()] Applying penalty: 110054.73652286574 kJ/mol
# ...
#  57%|█████▋    | 570/1000 [06:14<04:34,  1.57it/s, |force|=2.22e+4][ani.py:318 - _linear_penalty()] Applying penalty: 119444.31220751714 kJ/mol
#  57%|█████▋    | 571/1000 [06:15<04:33,  1.57it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 119916.37113424747 kJ/mol
#  57%|█████▋    | 572/1000 [06:16<04:36,  1.55it/s, |force|=2.15e+4][ani.py:318 - _linear_penalty()] Applying penalty: 117682.69245132671 kJ/mol
#  57%|█████▋    | 573/1000 [06:16<04:33,  1.56it/s, |force|=2.15e+4][ani.py:318 - _linear_penalty()] Applying penalty: 115345.20530315391 kJ/mol
#  57%|█████▋    | 574/1000 [06:17<04:32,  1.56it/s, |force|=21177.6][ani.py:318 - _linear_penalty()] Applying penalty: 113579.77701550553 kJ/mol
#  57%|█████▊    | 575/1000 [06:17<04:33,  1.56it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 110359.35627882555 kJ/mol
#  58%|█████▊    | 576/1000 [06:18<04:30,  1.57it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 105065.4588440151 kJ/mol
#  58%|█████▊    | 577/1000 [06:19<04:30,  1.57it/s, |force|=2.16e+4][ani.py:318 - _linear_penalty()] Applying penalty: 102844.76871268604 kJ/mol
#  58%|█████▊    | 578/1000 [06:19<04:31,  1.55it/s, |force|=2.21e+4][ani.py:318 - _linear_penalty()] Applying penalty: 106425.7887830086 kJ/mol
#  58%|█████▊    | 579/1000 [06:20<04:29,  1.56it/s, |force|=2.22e+4][ani.py:318 - _linear_penalty()] Applying penalty: 113475.60460195888 kJ/mol
#  58%|█████▊    | 580/1000 [06:21<04:27,  1.57it/s, |force|=2.22e+4][ani.py:318 - _linear_penalty()] Applying penalty: 120353.73546513212 kJ/mol
#  58%|█████▊    | 581/1000 [06:21<04:32,  1.54it/s, |force|=2.2e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 124281.84937734171 kJ/mol
#  58%|█████▊    | 582/1000 [06:22<04:29,  1.55it/s, |force|=2.2e+4][ani.py:318 - _linear_penalty()] Applying penalty: 129061.23897042118 kJ/mol
#  58%|█████▊    | 583/1000 [06:23<04:28,  1.55it/s, |force|=2.16e+4][ani.py:318 - _linear_penalty()] Applying penalty: 135013.16376058545 kJ/mol
#  58%|█████▊    | 584/1000 [06:23<04:23,  1.58it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 138593.48507118432 kJ/mol
#  58%|█████▊    | 585/1000 [06:24<04:20,  1.59it/s, |force|=2.02e+4][ani.py:318 - _linear_penalty()] Applying penalty: 138223.8851451018 kJ/mol
#  59%|█████▊    | 586/1000 [06:24<04:15,  1.62it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 140317.07607464085 kJ/mol
#  59%|█████▊    | 587/1000 [06:25<04:14,  1.63it/s, |force|=2.18e+4][ani.py:318 - _linear_penalty()] Applying penalty: 146754.5750692027 kJ/mol
#  59%|█████▉    | 588/1000 [06:26<04:13,  1.62it/s, |force|=2.24e+4][ani.py:318 - _linear_penalty()] Applying penalty: 154323.81119617165 kJ/mol
#  59%|█████▉    | 589/1000 [06:26<04:12,  1.63it/s, |force|=2.25e+4][ani.py:318 - _linear_penalty()] Applying penalty: 158901.6741306876 kJ/mol
#  59%|█████▉    | 590/1000 [06:27<04:08,  1.65it/s, |force|=2.24e+4][ani.py:318 - _linear_penalty()] Applying penalty: 161094.88013398324 kJ/mol
#  59%|█████▉    | 591/1000 [06:28<04:20,  1.57it/s, |force|=2.19e+4][ani.py:318 - _linear_penalty()] Applying penalty: 161388.70511611938 kJ/mol
#  59%|█████▉    | 592/1000 [06:28<04:12,  1.62it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 160126.04238701946 kJ/mol
#  59%|█████▉    | 593/1000 [06:29<04:06,  1.65it/s, |force|=2.06e+4][ani.py:318 - _linear_penalty()] Applying penalty: 157932.56511368934 kJ/mol
#  59%|█████▉    | 594/1000 [06:29<04:10,  1.62it/s, |force|=2.07e+4][ani.py:318 - _linear_penalty()] Applying penalty: 155254.49535120995 kJ/mol
#  60%|█████▉    | 595/1000 [06:30<04:11,  1.61it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 153712.9946463584 kJ/mol
#  60%|█████▉    | 596/1000 [06:31<04:11,  1.61it/s, |force|=2.15e+4][ani.py:318 - _linear_penalty()] Applying penalty: 152626.07120998632 kJ/mol
#  60%|█████▉    | 597/1000 [06:31<04:06,  1.63it/s, |force|=2.19e+4][ani.py:318 - _linear_penalty()] Applying penalty: 151501.38850065254 kJ/mol
#  60%|█████▉    | 598/1000 [06:32<04:02,  1.66it/s, |force|=2.22e+4][ani.py:318 - _linear_penalty()] Applying penalty: 151315.40986334736 kJ/mol
#  60%|█████▉    | 599/1000 [06:32<03:58,  1.68it/s, |force|=2.22e+4][ani.py:318 - _linear_penalty()] Applying penalty: 152628.33007244073 kJ/mol
#  60%|██████    | 600/1000 [06:33<03:56,  1.69it/s, |force|=2.19e+4][ani.py:318 - _linear_penalty()] Applying penalty: 154349.53424221778 kJ/mol
#  60%|██████    | 601/1000 [06:34<03:55,  1.69it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 157032.30552650985 kJ/mol
#  60%|██████    | 602/1000 [06:34<03:52,  1.71it/s, |force|=2.1e+4][ani.py:318 - _linear_penalty()] Applying penalty: 160480.5836951334 kJ/mol
#  60%|██████    | 603/1000 [06:35<03:49,  1.73it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 163273.8750719027 kJ/mol
#  60%|██████    | 604/1000 [06:35<03:48,  1.73it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 163267.72424512092 kJ/mol
#  60%|██████    | 605/1000 [06:36<03:49,  1.72it/s, |force|=2.13e+4][ani.py:318 - _linear_penalty()] Applying penalty: 161669.68646884008 kJ/mol
#  61%|██████    | 606/1000 [06:36<03:48,  1.73it/s, |force|=2.18e+4][ani.py:318 - _linear_penalty()] Applying penalty: 158766.92157039323 kJ/mol
#  61%|██████    | 607/1000 [06:37<03:46,  1.73it/s, |force|=2.17e+4][ani.py:318 - _linear_penalty()] Applying penalty: 153787.6544403651 kJ/mol
#  61%|██████    | 608/1000 [06:38<03:50,  1.70it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 147843.68612313876 kJ/mol
#  61%|██████    | 609/1000 [06:38<03:52,  1.68it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 142711.02052016795 kJ/mol
#  61%|██████    | 610/1000 [06:39<03:53,  1.67it/s, |force|=2.11e+4][ani.py:318 - _linear_penalty()] Applying penalty: 139955.77183649119 kJ/mol
#  61%|██████    | 611/1000 [06:39<03:54,  1.66it/s, |force|=2.11e+4][ani.py:318 - _linear_penalty()] Applying penalty: 140055.35693014195 kJ/mol
#  61%|██████    | 612/1000 [06:40<03:54,  1.66it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 141457.64810780136 kJ/mol
#  61%|██████▏   | 613/1000 [06:41<03:52,  1.66it/s, |force|=2.16e+4][ani.py:318 - _linear_penalty()] Applying penalty: 142830.08971133077 kJ/mol
#  61%|██████▏   | 614/1000 [06:41<03:52,  1.66it/s, |force|=2.2e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 143935.23517138706 kJ/mol
#  62%|██████▏   | 615/1000 [06:42<03:53,  1.65it/s, |force|=2.22e+4][ani.py:318 - _linear_penalty()] Applying penalty: 145828.49381029917 kJ/mol
#  62%|██████▏   | 616/1000 [06:42<03:52,  1.65it/s, |force|=2.21e+4][ani.py:318 - _linear_penalty()] Applying penalty: 148533.67847120503 kJ/mol
#  62%|██████▏   | 617/1000 [06:43<03:51,  1.65it/s, |force|=2.17e+4][ani.py:318 - _linear_penalty()] Applying penalty: 150907.07297257823 kJ/mol
#  62%|██████▏   | 618/1000 [06:44<03:53,  1.64it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 151169.33140080693 kJ/mol
#  62%|██████▏   | 619/1000 [06:44<03:52,  1.64it/s, |force|=2.13e+4][ani.py:318 - _linear_penalty()] Applying penalty: 149795.57144317112 kJ/mol
#  62%|██████▏   | 620/1000 [06:45<03:51,  1.64it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 147967.70729737516 kJ/mol
#  62%|██████▏   | 621/1000 [06:46<03:52,  1.63it/s, |force|=2.13e+4][ani.py:318 - _linear_penalty()] Applying penalty: 147657.9693923315 kJ/mol
#  62%|██████▏   | 622/1000 [06:46<03:51,  1.63it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 148907.62258225068 kJ/mol
#  62%|██████▏   | 623/1000 [06:47<03:51,  1.63it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 148994.25176759355 kJ/mol
#  62%|██████▏   | 624/1000 [06:47<03:50,  1.63it/s, |force|=2.13e+4][ani.py:318 - _linear_penalty()] Applying penalty: 147121.55005136307 kJ/mol
#  62%|██████▎   | 625/1000 [06:48<03:57,  1.58it/s, |force|=2.11e+4][ani.py:318 - _linear_penalty()] Applying penalty: 144015.48400734278 kJ/mol
#  63%|██████▎   | 626/1000 [06:49<03:55,  1.58it/s, |force|=2.07e+4][ani.py:318 - _linear_penalty()] Applying penalty: 140699.5021750375 kJ/mol
#  63%|██████▎   | 627/1000 [06:49<03:57,  1.57it/s, |force|=2.05e+4][ani.py:318 - _linear_penalty()] Applying penalty: 137400.76869585642 kJ/mol
#  63%|██████▎   | 628/1000 [06:50<03:54,  1.59it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 133938.05530115208 kJ/mol
#  63%|██████▎   | 629/1000 [06:51<03:51,  1.61it/s, |force|=2.18e+4][ani.py:318 - _linear_penalty()] Applying penalty: 131716.82469861707 kJ/mol
#  63%|██████▎   | 630/1000 [06:51<03:50,  1.61it/s, |force|=2.29e+4][ani.py:318 - _linear_penalty()] Applying penalty: 133168.79811413976 kJ/mol
#  63%|██████▎   | 631/1000 [06:52<04:04,  1.51it/s, |force|=2.32e+4][ani.py:318 - _linear_penalty()] Applying penalty: 137907.13133029116 kJ/mol
#  63%|██████▎   | 632/1000 [06:53<04:19,  1.42it/s, |force|=2.27e+4][ani.py:318 - _linear_penalty()] Applying penalty: 142422.72705628004 kJ/mol
#  63%|██████▎   | 633/1000 [06:53<04:22,  1.40it/s, |force|=2.21e+4][ani.py:318 - _linear_penalty()] Applying penalty: 144967.28401966364 kJ/mol
#  63%|██████▎   | 634/1000 [06:54<04:25,  1.38it/s, |force|=2.16e+4][ani.py:318 - _linear_penalty()] Applying penalty: 146951.45689314528 kJ/mol
#  64%|██████▎   | 635/1000 [06:55<04:26,  1.37it/s, |force|=2.12e+4][ani.py:318 - _linear_penalty()] Applying penalty: 148601.4822222603 kJ/mol
#  64%|██████▎   | 636/1000 [06:56<04:24,  1.38it/s, |force|=2.1e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 147622.15824110457 kJ/mol
#  64%|██████▎   | 637/1000 [06:56<04:21,  1.39it/s, |force|=2.1e+4][ani.py:318 - _linear_penalty()] Applying penalty: 144213.4493762925 kJ/mol
#  64%|██████▍   | 638/1000 [06:57<04:27,  1.35it/s, |force|=2.16e+4][ani.py:318 - _linear_penalty()] Applying penalty: 142436.22239730094 kJ/mol
#  64%|██████▍   | 639/1000 [06:58<04:23,  1.37it/s, |force|=2.17e+4][ani.py:318 - _linear_penalty()] Applying penalty: 139922.6389204945 kJ/mol
#  64%|██████▍   | 640/1000 [06:59<04:23,  1.37it/s, |force|=2.18e+4][ani.py:318 - _linear_penalty()] Applying penalty: 133795.55638306236 kJ/mol
#  64%|██████▍   | 641/1000 [06:59<04:13,  1.42it/s, |force|=2.19e+4][ani.py:318 - _linear_penalty()] Applying penalty: 126499.51981483368 kJ/mol
#  64%|██████▍   | 642/1000 [07:00<04:14,  1.41it/s, |force|=2.15e+4][ani.py:318 - _linear_penalty()] Applying penalty: 120150.81785457606 kJ/mol
#  64%|██████▍   | 643/1000 [07:01<04:09,  1.43it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 114238.22662617764 kJ/mol
#  64%|██████▍   | 644/1000 [07:01<04:16,  1.39it/s, |force|=2.07e+4][ani.py:318 - _linear_penalty()] Applying penalty: 108331.2734470262 kJ/mol
#  64%|██████▍   | 645/1000 [07:02<04:14,  1.40it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 103326.68126345734 kJ/mol
#  65%|██████▍   | 646/1000 [07:03<04:10,  1.41it/s, |force|=2.14e+4][ani.py:318 - _linear_penalty()] Applying penalty: 100048.20831522063 kJ/mol
#  65%|██████▍   | 647/1000 [07:03<04:05,  1.44it/s, |force|=2.2e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 99218.46668563088 kJ/mol
#  65%|██████▍   | 648/1000 [07:04<04:08,  1.42it/s, |force|=2.23e+4][ani.py:318 - _linear_penalty()] Applying penalty: 100726.6992324557 kJ/mol
#  65%|██████▍   | 649/1000 [07:05<04:06,  1.42it/s, |force|=2.24e+4][ani.py:318 - _linear_penalty()] Applying penalty: 105164.74576586604 kJ/mol
#  65%|██████▌   | 650/1000 [07:06<04:08,  1.41it/s, |force|=2.24e+4][ani.py:318 - _linear_penalty()] Applying penalty: 111833.22194948606 kJ/mol
#  65%|██████▌   | 651/1000 [07:06<04:03,  1.43it/s, |force|=2.19e+4][ani.py:318 - _linear_penalty()] Applying penalty: 118795.97088679155 kJ/mol
#  65%|██████▌   | 652/1000 [07:07<04:02,  1.43it/s, |force|=2.13e+4][ani.py:318 - _linear_penalty()] Applying penalty: 124980.6572566194 kJ/mol
#  65%|██████▌   | 653/1000 [07:08<04:04,  1.42it/s, |force|=2.09e+4][ani.py:318 - _linear_penalty()] Applying penalty: 130147.59591029017 kJ/mol
#  65%|██████▌   | 654/1000 [07:08<04:01,  1.44it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 132497.8864490014 kJ/mol
#  66%|██████▌   | 655/1000 [07:09<03:57,  1.45it/s, |force|=2.1e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 131948.19808316045 kJ/mol
#  66%|██████▌   | 656/1000 [07:10<04:00,  1.43it/s, |force|=2.17e+4][ani.py:318 - _linear_penalty()] Applying penalty: 131453.44942194657 kJ/mol
#  66%|██████▌   | 657/1000 [07:10<03:56,  1.45it/s, |force|=2.24e+4][ani.py:318 - _linear_penalty()] Applying penalty: 131050.71478305612 kJ/mol
#  66%|██████▌   | 658/1000 [07:11<03:56,  1.45it/s, |force|=2.28e+4][ani.py:318 - _linear_penalty()] Applying penalty: 130405.11315004606 kJ/mol
#  66%|██████▌   | 659/1000 [07:12<03:55,  1.45it/s, |force|=2.26e+4][ani.py:318 - _linear_penalty()] Applying penalty: 130018.75553330785 kJ/mol
#  66%|██████▌   | 660/1000 [07:13<03:56,  1.44it/s, |force|=2.18e+4][ani.py:318 - _linear_penalty()] Applying penalty: 130079.16741582192 kJ/mol
#  66%|██████▌   | 661/1000 [07:13<03:54,  1.45it/s, |force|=2.07e+4][ani.py:318 - _linear_penalty()] Applying penalty: 131000.40262778474 kJ/mol
#  66%|██████▌   | 662/1000 [07:14<03:50,  1.46it/s, |force|=2.02e+4][ani.py:318 - _linear_penalty()] Applying penalty: 133507.7146641529 kJ/mol
#  66%|██████▋   | 663/1000 [07:15<03:46,  1.49it/s, |force|=2.08e+4][ani.py:318 - _linear_penalty()] Applying penalty: 137776.34049063106 kJ/mol
#  66%|██████▋   | 664/1000 [07:15<03:47,  1.48it/s, |force|=2.2e+4] [ani.py:318 - _linear_penalty()] Applying penalty: 144283.25849880287 kJ/mol
#  66%|██████▋   | 665/1000 [07:16<03:46,  1.48it/s, |force|=2.31e+4][ani.py:318 - _linear_penalty()] Applying penalty: 152749.0794397943 kJ/mol
#  67%|██████▋   | 666/1000 [07:17<03:48,  1.46it/s, |force|=2.37e+4][ani.py:318 - _linear_penalty()] Applying penalty: 162823.3181496829 kJ/mol
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-10693bd6cc9a> in <module>
#     119                                                                 n_steps=round(n_steps),
#     120                                                                 stepsize=0.5 * unit.femtosecond,
# --> 121                                                                 progress_bar=True)
#     122
#     123     # set new x0
#
# ~/anaconda3/envs/ani36/lib/python3.6/site-packages/neutromeratio-0.0.0+485.g848475f.dirty-py3.6.egg/neutromeratio/equilibrium.py in run_dynamics(self, x0, n_steps, stepsize, collision_rate, progress_bar)
#      97             # r
#      98             x += (stepsize * 0.5) * v
# ---> 99             F, E, B, S, P = self.energy_and_force(x)
#     100             energy.append(E)
#     101             bias.append(B)
#
# <ipython-input-1-10693bd6cc9a> in <lambda>(x)
#     100
#     101 print(lambda_value)
# --> 102 energy_and_force = lambda x : energy_function.calculate_force(x, lambda_value)
#     103 langevin = neutromeratio.LangevinDynamics(atoms = tautomer.ligand_in_water_atoms,
#     104                             energy_and_force = energy_and_force)
#
# ~/anaconda3/envs/ani36/lib/python3.6/site-packages/neutromeratio-0.0.0+485.g848475f.dirty-py3.6.egg/neutromeratio/ani.py in calculate_force(self, x, lambda_value)
#     225
#     226         # derivative of E (in kJ/mol) w.r.t. coordinates (in nm)
# --> 227         derivative = torch.autograd.grad((energy_in_kJ_mol).sum(), coordinates)[0]
#     228
#     229         if self.platform == 'cpu':
#
# ~/anaconda3/envs/ani36/lib/python3.6/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     155     return Variable._execution_engine.run_backward(
#     156         outputs, grad_outputs, retain_graph, create_graph,
# --> 157         inputs, allow_unused)
#     158
#     159
#
# KeyboardInterrupt:
