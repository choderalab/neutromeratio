# %%
import neutromeratio
from openmmtools.constants import kB
from simtk import unit
import numpy as np
import pickle
import mdtraj as md
import torchani
import torch
from tqdm import tqdm
import matplotlib.pyplot as plt
import random, sys
from neutromeratio.constants import platform, device
import pandas as pd
from neutromeratio.constants import kT
from neutromeratio.plotting import plot_correlation_analysis


# extract smiles
exp_results = pickle.load(open('../data/exp_results.pickle', 'rb'))
# Out:
# _ColormakerRegistry()
# [utils.py:141 - _init_num_threads()] NumExpr defaulting to 8 threads.

# %%
d1 = pickle.load(open('../data/results/EXPERIMENT_solv.pickle', 'rb'))
plt.hist(list(d1.loc['energy [kT]']), bins=40)
plt.xlabel('dG in kT', size=18)
plt.title('dG values in solution in the tautomer database (tautomer pairs {}'.format(len(d1.loc['energy [kT]'])))

# %%
sys = pd.read_csv('../data/results/ANI1ccx_vacuum_global_minimum_dE_with_entropy_correction.csv', names=['names', 'energy [kT]'], index_col=0).transpose()
sys
sys.to_pickle('../data/results/ANI1ccx_vacuum_global_minimum_dE_with_entropy_correction.pickle')

# %%
alchemical_solv_dG = global_dE
alchemical_solv_dG

# %%
df = pd.read_csv('../data/results/csv/MM_ANI1ccx_vacuum_with_entropy_correction.csv', names=['names', 'energy [kT]', 't1-confs', 't2-confs'], index_col=0).transpose()
df.to_pickle('../data/results/ANI1ccx_vacuum_mining_minima_with_entropy_correction.pickle')
df

# %%
entropy_correction['SAMPLmol2']['t1-entropy-correction [kT]']

# %%
d2e

# %%
d1 = pickle.load(open('../data/results/EXPERIMENT_solv.pickle', 'rb'))

d2 = pickle.load(open('../data/results/ANI1ccx_vacuum_global_minimum_dE.pickle', 'rb'))
d2e = pickle.load(open('../data/results/ANI1ccx_vacuum_global_minimum_dE_with_entropy_correction.pickle', 'rb'))
d3 = pickle.load(open('../data/results/ANI1ccx_vacuum_random_minimum_dE.pickle', 'rb'))
d3e = pickle.load(open('../data/results/ANI1ccx_vacuum_random_minimum_dE_with_entropy_correction.pickle', 'rb'))

d4 = pickle.load(open('../data/results/ANI1ccx_vacuum_global_minimum_dG.pickle', 'rb'))
d4e = pickle.load(open('../data/results/ANI1ccx_vacuum_global_minimum_dG_with_entropy_correction.pickle', 'rb'))
d5 = pickle.load(open('../data/results/ANI1ccx_vacuum_random_minimum_dG.pickle', 'rb'))
d5e = pickle.load(open('../data/results/ANI1ccx_vacuum_random_minimum_dG_with_entropy_correction.pickle', 'rb'))

d6 = pickle.load(open('../data/results/ANI1ccx_vacuum_mining_minima_dG.pickle', 'rb'))
energy = {}
for a, name in zip(list(d6.loc['energy [kT]']), list(d6.columns)):
    energy[name] =     float(a) 
d6 = pd.DataFrame().from_dict(energy, orient='index', columns=['energy [kT]']).transpose()

d6e = pickle.load(open('../data/results/ANI1ccx_vacuum_mining_minima_dG_with_entropy_correction.pickle', 'rb'))
energy = {}
for a, name in zip(list(d6e.loc['energy [kT]']), list(d6e.columns)):
    energy[name] =     float(a) 
d6e = pd.DataFrame().from_dict(energy, orient='index', columns=['energy [kT]']).transpose()


d7 = pickle.load(open('../data/results/ANI1ccx_vacuum_alchemical_dG.pickle', 'rb'))
energy = {}
for a, name in zip(list(d7.loc['energy [kT]']), list(d7.columns)):
    energy[name] =     float(a) 
d7 = pd.DataFrame().from_dict(energy, orient='index', columns=['energy [kT]']).transpose()

d8f = pickle.load(open('../data/results/ANI1ccx_droplet_18A_alchemical_dG_filtered.pickle', 'rb'))
energy = {}
for a, name in zip(list(d8f.loc['energy [kT]']), list(d8f.columns)):
    energy[name] =     float(a) 
d8f = pd.DataFrame().from_dict(energy, orient='index', columns=['energy [kT]']).transpose()

d8u = pickle.load(open('../data/results/ANI1ccx_droplet_18A_alchemical_dG_unfiltered.pickle', 'rb'))
energy = {}
for a, name in zip(list(d8u.loc['energy [kT]']), list(d8u.columns)):
    energy[name] =     float(a) 
d8u = pd.DataFrame().from_dict(energy, orient='index', columns=['energy [kT]']).transpose()


d9 = pickle.load(open('../data/results/DFT_vac_global_minimum_dG.pickle', 'rb'))
d10 = pickle.load(open('../data/results/DFT_solv_global_minimum_dG.pickle', 'rb'))
d11 = pickle.load(open('../data/results/DFT_vac_mining_minima_dG.pickle', 'rb'))
d12 = pickle.load(open('../data/results/DFT_solv_mining_minima_dG.pickle', 'rb'))

# %%
d3 - d3e

# %%
for d in [d2,d2e,d3,d3e,d4,d4e,d5,d5e,d6,d6e, d7,d8f,d8u,d9,d10,d11,d12]:
    d1 = d1.merge(d, how='outer')


d1.index = ['EXPERIMENT_solv', 'ANI1ccx_vacuum_global_minimum_dE', 'ANI1ccx_vacuum_global_minimum_dE_entropy_correction','ANI1ccx_vacuum_random_minimum_dE', 'ANI1ccx_vacuum_random_minimum_dE_entropy_correction','ANI1ccx_vacuum_global_minimum_dG', 'ANI1ccx_vacuum_global_minimum_dG_entropy_correction', 'ANI1ccx_vacuum_random_minimum_dG', 'ANI1ccx_vacuum_random_minimum_dG_entropy_correction', 'ANI1ccx_vacuum_mining_minima_dG', 'ANI1ccx_vacuum_mining_minima_dG_with_entropy_correction', 'ANI1ccx_vacuum_alchemical_dG', 'ANI1ccx_droplet_18A_alchemical_dG_filtered', 'ANI1ccx_droplet_18A_alchemical_dG_unfiltered', 'DFT_vac_global_minimum_dG', 'DFT_solv_global_minimum_dG', 'DFT_vac_mining_minima_dG', 'DFT_solv_mining_minima_dG']
d1
# Out:
#                                                     SAMPLmol2  SAMPLmol4  \
# EXPERIMENT_solv                                    -10.232118  -3.858012
# ANI1ccx_vacuum_global_minimum_dE                    -4.710662   3.958960
# ANI1ccx_vacuum_global_minimum_dE_entropy_correc...  -4.710662   3.958960
# ANI1ccx_vacuum_random_minimum_dE                   -22.901834  -8.569395
# ANI1ccx_vacuum_random_minimum_dE_entropy_correc... -22.901834  -8.569395
# ANI1ccx_vacuum_global_minimum_dG                    -4.350346   4.439954
# ANI1ccx_vacuum_global_minimum_dG_entropy_correc...  -5.736640   3.053659
# ANI1ccx_vacuum_random_minimum_dG                   -18.989632  -7.081554
# ANI1ccx_vacuum_random_minimum_dG_entropy_correc... -20.375926  -8.467849
# ANI1ccx_vacuum_mining_minima_dG                     -4.350156   5.772085
# ANI1ccx_vacuum_mining_minima_dG_with_entropy_co...  -5.736451   4.385791
# ANI1ccx_vacuum_alchemical_dG                        -5.696215   4.030382
# ...

# %%
d1.to_pickle('../data/results/combined_results_in_kT.pickle')

# %%
d1

# %%
d1 = pickle.load(open('../data/results/EXPERIMENT_solv.pickle', 'rb'))


d8 = pickle.load(open('../data/results/ANI1ccx_droplet_18A_alchemical_dG_filtered.pickle', 'rb'))
energy = {}
for a, name in zip(list(d8.loc['energy [kT]']), list(d8.columns)):
    energy[name] =     float(a) 
d8 = pd.DataFrame().from_dict(energy, orient='index', columns=['energy [kT]']).transpose()

# %%
p12 = d1.merge(d8, how='outer')

p12.index = ['EXPERIMENT_solv', 'ANI1ccx_solv']
#p12.to_pickle('../data/results/combined_results_in_kT.pickle')

# %%
p12

# %%
d1

# %%
p12

# %%
x_list = []
y_list = []

for a in list(d1.loc['ANI1ccx_droplet_18A_alchemical_dG_filtered']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(d1.loc['ANI1ccx_droplet_18A_alchemical_dG_unfiltered']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
#for i in range(len(x_list)):
#    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(d1.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
fig = plt.figure(figsize=[8,8], dpi=300)

f = plot_correlation_analysis(df, 'ANI1ccx droplet alchemical dG filtered vs unfiltered conformations', 'Filtered conformations ANI1ccx dG [kcal/mol]', 'Unfiltered conformations ANI1ccx dG [kcal/mol]', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(d1.loc['ANI1ccx_vacuum_mining_minima_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(d1.loc['ANI1ccx_vacuum_global_minimum_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
#for i in range(len(x_list)):
#    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(d1.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx vacuum mining minima dG vs ANI1ccx vacuum global minimum dG + symmetry correction', 'ANI1ccx dG [kcal/mol]', 'ANI1ccx dG mining minima  [kcal/mol]', 'g', 'o')
#f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(d1.loc['ANI1ccx_vacuum_mining_minima_dG_with_entropy_correction']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(d1.loc['ANI1ccx_vacuum_global_minimum_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
#for i in range(len(x_list)):
#    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(d1.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx vacuum mining minima dG vs ANI1ccx vacuum global minimum dG + symmetry correction', 'ANI1ccx dG [kcal/mol]', 'ANI1ccx dG mining minima  [kcal/mol]', 'g', 'o')
#f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(d1.loc['ANI1ccx_vacuum_global_minimum_dG_entropy_correction']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(d1.loc['ANI1ccx_vacuum_global_minimum_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
#for i in range(len(x_list)):
#    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(d1.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx vacuum mining minima dG vs ANI1ccx vacuum global minimum dG + symmetry correction', 'ANI1ccx dG [kcal/mol]', 'ANI1ccx dG mining minima  [kcal/mol]', 'g', 'o')
#f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(d1.loc['ANI1ccx_vacuum_mining_minima_dG_with_entropy_correction']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(d1.loc['ANI1ccx_vacuum_alchemical_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
#for i in range(len(x_list)):
#    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(d1.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx vacuum mining minima dG vs ANI1ccx vacuum global minimum dG + symmetry correction', 'ANI1ccx dG [kcal/mol]', 'ANI1ccx dG mining minima  [kcal/mol]', 'g', 'o')
#f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(d1.loc['ANI1ccx_vacuum_mining_minima_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(d1.loc['ANI1ccx_vacuum_alchemical_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
#for i in range(len(x_list)):
#    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(d1.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx vacuum mining minima dG vs ANI1ccx vacuum global minimum dG + symmetry correction', 'ANI1ccx dG [kcal/mol]', 'ANI1ccx dG mining minima  [kcal/mol]', 'g', 'o')
#f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a, c in zip(list(p1234567891011.loc['ANI1ccx_vacuum_global_minimum_dG']), list(p1234567891011.loc['entropy_correction'])):
    a = (a -c) *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(p1234567891011.loc['ANI1ccx_vacuum_random_minimum_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
for i in range(len(x_list)):
    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(p1234567891011.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx global minimum dG vs ramdom minimum dG', 'global minimum dG [kcal/mol]', 'random minimum dG [kcal/mol]', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(p1234567891011.loc['ANI1ccx_vacuum_global_minimum_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(p1234567891011.loc['ANI1ccx_vacuum_mining_minima_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
for i in range(len(x_list)):
    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(p1234567891011.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx global minimum dG vs mining minima dG', 'global minimum dG [kcal/mol]', 'mining minima dG [kcal/mol]', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(p1234567891011.loc['ANI1ccx_vacuum_alchemical_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a, c in zip(list(p1234567891011.loc['ANI1ccx_vacuum_mining_minima_dG']), list(p1234567891011.loc['entropy_correction'])):
    #c = 0.0
    a = (a + c) *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
for i in range(len(x_list)):
    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(p1234567891011.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx alchemical dG vs mining minima dG', 'alchemical dG [kcal/mol]', 'mining minima dG [kcal/mol]', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(p1234567891011.loc['ANI1ccx_vacuum_global_minimum_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a, c in zip(list(p1234567891011.loc['ANI1ccx_vacuum_global_minimum_dG']), list(p1234567891011.loc['entropy_correction'])):
    #c = 0.0
    a = (a - c) *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
for i in range(len(x_list)):
    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(p1234567891011.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx alchemical dG vs mining minima dG', 'alchemical dG [kcal/mol]', 'mining minima dG [kcal/mol]', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(p1234567891011.loc['ANI1ccx_vacuum_alchemical_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(p1234567891011.loc['ANI1ccx_vacuum_mining_minima_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
for i in range(len(x_list)):
    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(p1234567891011.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx global minimum dG vs ramdom minimum dG', 'global minimum dG [kcal/mol]', 'random minimum dG [kcal/mol]', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(p1234567891011.loc['ANI1ccx_vacuum_alchemical_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(p1234567891011.loc['DFT_vac_mining_minima_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
for i in range(len(x_list)):
    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(p1234567891011.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx alchemical dG vs IG-RRHO/B3LYP/aug-cc-pVTZ mining minimum', 'ANI1ccx alchemical dG [kcal/mol] in vacuum', 'DFT dG mining minimum [kcal/mol] in vacuum', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(p1234567891011.loc['ANI1ccx_vacuum_alchemical_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(p1234567891011.loc['DFT_vac_minimum_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
for i in range(len(x_list)):
    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(p1234567891011.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx alchemical dG vs IG-RRHO/B3LYP/aug-cc-pVTZ single minimum', 'ANI1ccx alchemical dG [kcal/mol] in vacuum', 'DFT dG single minimum [kcal/mol] in vacuum', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(p1234567.loc['ANI1ccx_vacuum_alchemical_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(p1234567.loc['ANI1ccx_vacuum_minimum_dE']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
for i in range(len(x_list)):
    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(p1234567.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx alchemical dG vs ANI1ccx dE single minimum', 'ANI1ccx alchemical dG [kcal/mol] in vacuum', 'ANI1ccx dE single minimum [kcal/mol] in vacuum', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(p123456789.loc['ANI1ccx_vacuum_alchemical_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(p123456789.loc['ANI1ccx_vacuum_single_conf_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
for i in range(len(x_list)):
    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(p123456789.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx alchemical dG vs ANI1ccx single minimum dG', 'ANI1ccx alchemical dG [kcal/mol] in vacuum', 'ANI1ccx single minimum dG [kcal/mol] in vacuum', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
x_list = []
y_list = []

for a in list(p123456789.loc['ANI1ccx_vacuum_alchemical_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    x_list.append(a)
    
for a in list(p123456789.loc['ANI1ccx_vacuum_mining_minima_dG']):
    a = a *kT
    a = a.value_in_unit(unit.kilocalorie_per_mole)
    y_list.append(a)

absolute_error = []
for i in range(len(x_list)):
    absolute_error.append(abs(y_list[i] - x_list[i]))
    
    
df = pd.DataFrame(list(zip(list(p123456789.columns), x_list, y_list)), columns =['names', 'x', 'y']) 
df = df.dropna(axis=0)
f = plot_correlation_analysis(df, 'ANI1ccx alchemical dG vs ANI1ccx single minimum dG', 'ANI1ccx alchemical dG [kcal/mol] in vacuum', 'ANI1ccx single minimum dG [kcal/mol] in vacuum', 'g', 'o')
f.savefig('/home/mwieder/fig.png')

# %%
csv_df = pd.read_csv('../data/results/ANI1ccx_vacuum_MM_kcal.csv', names=['names', 'energy'])
csv_df

# %%
d5.columns

# %%
r = pickle.load(open('results.pickle', 'rb'))
r

# %%
sorted_mm_energies = []
for n in r['names']:
    sorted_mm_energies.append(MM_energy[n])

# %%
r['dG_MM'] = sorted_mm_energies

# %%
new_pd = r.rename(columns={"experimental_values" : "experimental_values [kT]", "ddG_DFT": "free energy difference in vacuum with B3LYP/aug-cc-pVTZ (difference between minimum conformations) [kT]", 
        "dE_ani1ccx" : "single point energy difference in vacuum with ANI1-ccx [kT]",
        "dG_ani1ccx" : "free energy difference in vacuum with ANI1-ccx [kT]", 
        "dG_MM" : 'free energy difference in vacuum using the Mining Minima approach with ANI1-ccx [kT]'})

# %%
new_pd.to_pickle('current_results.pckl')

# %%
new_pd

# %%
import random

# %%
a = [-5,-4,-3,-2,0,2,3,4,5]
b = [-5,-4,-3,-2,0,2,3,4,5]

# %%
min(b) - min(a)

# %%
random.choice(b) - random.choice(a)

# %%
import random

a = [-5,-4,-3,-2,0]
b = [-5,-4,-3,-2,0]

print(f"Min diff: {min(b) - min(a)}")
print(f"Random diff: {random.choice(b) - random.choice(a)}")
